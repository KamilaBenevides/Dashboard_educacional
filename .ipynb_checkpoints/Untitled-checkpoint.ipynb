# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from metrics import *
import matplotlib.pyplot as plt
import shap
import seaborn as sns
from scipy.stats import linregress
# Out:
# /home/kamila/.pyenv/versions/3.9.0/lib/python3.9/site-packages/xgboost/core.py:265: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc 2.28+) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
df = pd.read_csv('novas_30_colunas.csv', encoding='ISO-8859-1')

# %%
pd.set_option('display.max_columns', None)

# %%
escola_id = 31081485
escola_data = df[df['ID_ESCOLA'] == escola_id]
print(escola_data)
# Out:
#       A006B_pais_incentiva_estudar  A013_ingressou_aos_8_ou_mais  \
# 4751                           0.0                           0.0
#
#       A003E_outros_familiares_moram_cmg  A009E_2_tvs_em_casa  \
# 4751                                0.0                  0.0
#
#       A010F_tem_microondas  A006D_familiar_incentiva_ir_as_aulas  \
# 4751                   0.0                                   0.0
#
#       A010H_tem_lavadora_roupas  A006A_pais_sempre_conversam_sobre_escola  \
# 4751                        0.0                                       0.0
#
#       A014_estudou_escola_publica_particular  A018C_nunca_le_quadrinhos  \
# 4751                                     0.0                        0.0
#
#       A009D_1_quarto_em_casa  A017A_nao_tem_lazer  A018B_nuca_le_livros  \
# 4751                     0.0                  0.0                   0.0
#
#       A010I_tem_freezer  A011_mais_de_1_hora_chegar_escola  \
# 4751                0.0                                0.0
#
# ...

# %%
caminho_arquivo = '../DADOS/TS_ALUNO_34EM.csv' 
dados_aluno = pd.read_csv(caminho_arquivo, encoding='ISO-8859-1', sep=",")
dados_aluno

# %%
escola_id = 31081485
escola_data = dados_aluno[dados_aluno['ID_ESCOLA'] == escola_id]
# Out:
#         ID_SAEB  ID_REGIAO  ID_UF  ID_MUNICIPIO  ID_AREA  ID_ESCOLA  \
# 699176     2019       True     31       3143302     True   31081485
# 699177     2019       True     31       3143302     True   31081485
# 699178     2019       True     31       3143302     True   31081485
# 699179     2019       True     31       3143302     True   31081485
# 699180     2019       True     31       3143302     True   31081485
# ...         ...        ...    ...           ...      ...        ...
# 699247     2019       True     31       3143302     True   31081485
# 699248     2019       True     31       3143302     True   31081485
# 699249     2019       True     31       3143302     True   31081485
# 699250     2019       True     31       3143302     True   31081485
# 699251     2019       True     31       3143302     True   31081485
#
#         ID_DEPENDENCIA_ADM  ID_LOCALIZACAO  ID_TURMA  ID_TURNO  ...  \
# 699176                True            True    976056         1  ...
# ...

# %%
#pd.set_option('display.max_columns', None)

# %%
# Out:
#         ID_SAEB  ID_REGIAO  ID_UF  ID_MUNICIPIO  ID_AREA  ID_ESCOLA  \
# 699176     2019       True     31       3143302     True   31081485
# 699177     2019       True     31       3143302     True   31081485
# 699178     2019       True     31       3143302     True   31081485
# 699179     2019       True     31       3143302     True   31081485
# 699180     2019       True     31       3143302     True   31081485
# ...         ...        ...    ...           ...      ...        ...
# 699247     2019       True     31       3143302     True   31081485
# 699248     2019       True     31       3143302     True   31081485
# 699249     2019       True     31       3143302     True   31081485
# 699250     2019       True     31       3143302     True   31081485
# 699251     2019       True     31       3143302     True   31081485
#
#         ID_DEPENDENCIA_ADM  ID_LOCALIZACAO  ID_TURMA  ID_TURNO  ID_SERIE  \
# 699176                True            True    976056         1      True
# ...

# %%
def contar_booleanos(dados_aluno):
    for coluna in dados_aluno.columns:
        if df[coluna].dtype == 'bool':
            true_count = df[coluna].sum()
            false_count = (~df[coluna]).sum()
            print(f"Coluna: {coluna} | True: {true_count} | False: {false_count}")

contar_booleanos(escola_data)
# Out:
# Coluna: ID_REGIAO | True: 76 | False: 0
# Coluna: ID_AREA | True: 76 | False: 0
# Coluna: ID_DEPENDENCIA_ADM | True: 76 | False: 0
# Coluna: ID_LOCALIZACAO | True: 76 | False: 0
# Coluna: ID_SERIE | True: 76 | False: 0
# Coluna: TX_RESP_Q002_Branca | True: 0 | False: 76
# Coluna: TX_RESP_Q002_Preta | True: 0 | False: 76
# Coluna: TX_RESP_Q002_Parda | True: 0 | False: 76
# Coluna: TX_RESP_Q002_Amarela | True: 0 | False: 76
# Coluna: TX_RESP_Q002_Indigena | True: 0 | False: 76
# Coluna: TX_RESP_Q002_Nao_Declarado | True: 0 | False: 76
# Coluna: TX_RESP_Q002 | True: 0 | False: 76
# Coluna: TX_RESP_Q003A_Nao_moro_com_mae_madrasta | True: 0 | False: 76
# Coluna: TX_RESP_Q003A_Sim_moro_com_mae_madrasta | True: 0 | False: 76
# Coluna: TX_RESP_Q003A | True: 0 | False: 76
# Coluna: TX_RESP_Q003B_Nao_moro_com_pai_padrasto | True: 0 | False: 76
# Coluna: TX_RESP_Q003B_Sim_moro_com_pai_padrasto | True: 0 | False: 76
# Coluna: TX_RESP_Q003B | True: 0 | False: 76
# ...
