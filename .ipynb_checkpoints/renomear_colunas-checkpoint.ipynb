# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset_reduzido.csv')

# %%
df.columns
# Out:
# Index(['ALUNOS_PORCENTAGEM_Q003E_Sim_moro_com_outros',
#        'ALUNOS_PORCENTAGEM_Q014_Abandonou_Escola_Publica_Particular',
#        'ALUNOS_PORCENTAGEM_Q010B_Sim_Wifi',
#        'ALUNOS_PORCENTAGEM_Q009C_1_Computador_Em_Casa',
#        'ALUNOS_PORCENTAGEM_Q013_Idade_Ingresso_Escola_8_Ou_Mais',
#        'ALUNOS_PORCENTAGEM_Q009D_1_Quartos_Em_Casa',
#        'ALUNOS_PORCENTAGEM_Q010E_Sim_Garagem',
#        'ALUNOS_PORCENTAGEM_Q010F_Sim_Microondas',
#        'ALUNOS_PORCENTAGEM_Q011_Mais_1_Hora',
#        'ALUNOS_PORCENTAGEM_Q003D_Nao_moro_com_avos',
#        'ALUNOS_PORCENTAGEM_Q009E_2_Televisao_Em_Casa',
#        'ALUNOS_PORCENTAGEM_Q017C_Trabalhos_Domesticos_1_a_2_Horas',
#        'ALUNOS_PORCENTAGEM_Q003C_Nao_moro_com_irmaos',
#        'ALUNOS_PORCENTAGEM_Q004_Mae_Nao_Sabe_Escolaridade',
#        'ALUNOS_PORCENTAGEM_Q009G_Nenhum_Carro_Em_Casa',
#        'ALUNOS_PORCENTAGEM_Q015_Reprovado_Nunca',
#        'ALUNOS_PORCENTAGEM_Q018A_Le_Noticias_Quase_Sempre',
# ...

# %%
df = df.rename(columns={
    'ALUNOS_PORCENTAGEM_Q003E_Sim_moro_com_outros': 'A003E_outros_familiares_moram_cmg',
    'ALUNOS_PORCENTAGEM_Q014_Abandonou_Escola_Publica_Particular': 'A014_estudou_escola_publica_particular',
    'ALUNOS_PORCENTAGEM_Q010B_Sim_Wifi': 'A010B_tem_wifi',
    'ALUNOS_PORCENTAGEM_Q009C_1_Computador_Em_Casa': 'A009C_1_pc_em_casa',
    'ALUNOS_PORCENTAGEM_Q013_Idade_Ingresso_Escola_8_Ou_Mais': 'A013_ingressou_aos_8_ou_mais',
    'ALUNOS_PORCENTAGEM_Q009D_1_Quartos_Em_Casa': 'A009D_1_quarto_em_casa',
    'ALUNOS_PORCENTAGEM_Q010E_Sim_Garagem': 'A010E_tem_garagem',
    'ALUNOS_PORCENTAGEM_Q010F_Sim_Microondas': 'A010F_tem_microondas',
    'ALUNOS_PORCENTAGEM_Q011_Mais_1_Hora': 'A011_mais_de_1_hora_chegar_escola',
    'ALUNOS_PORCENTAGEM_Q003D_Nao_moro_com_avos': 'A003D_nao_moro_com_avos',
    'ALUNOS_PORCENTAGEM_Q009E_2_Televisao_Em_Casa': 'A009E_2_tvs_em_casa',
    'ALUNOS_PORCENTAGEM_Q017C_Trabalhos_Domesticos_1_a_2_Horas': 'A017C_trabalho_domestico_1_a_2_horas',
    'ALUNOS_PORCENTAGEM_Q003C_Nao_moro_com_irmaos': 'A003C_nao_moro_com_irmaos',
    'ALUNOS_PORCENTAGEM_Q004_Mae_Nao_Sabe_Escolaridade': 'A004_nao_sabe_escolaridade_mae',
    'ALUNOS_PORCENTAGEM_Q009G_Nenhum_Carro_Em_Casa': 'A009G_nenhum_carro_em_casa',
    'ALUNOS_PORCENTAGEM_Q015_Reprovado_Nunca': 'A015_nunca_foi_reprovado',
    'ALUNOS_PORCENTAGEM_Q018A_Le_Noticias_Quase_Sempre': 'A018A_sempre_le_noticias',
    'ALUNOS_PORCENTAGEM_Q017A_Lazer_Nao_Uso_Tempo_Nisso': 'A017A_nao_tem_lazer',
    'ALUNOS_PORCENTAGEM_Q010C_Sim_Quarto_So_Meu': 'A010C_tem_quarto_so_meu',
    'ALUNOS_PORCENTAGEM_Q020_Nao_Concluiu_EM_Eja': 'A020_nao_concluiu_eja',
    'ALUNOS_PORCENTAGEM_Q019_Depois_EM_Somente_Trabalhar': 'A019_depois_em_so_trabalhar',
    'ALUNOS_PORCENTAGEM_Q006A_Conversa_Sobre_Escola_Quase_Sempre': 'A006A_pais_sempre_conversam_sobre_escola',
    'ALUNOS_PORCENTAGEM_Q010D_Sim_Mesa_Estudo': 'A010D_tem_mesa_de_estudo',
    'ALUNOS_PORCENTAGEM_Q017E_Trabalhar_Mais_2_Hora': 'A017E_trabalha_mais_de_2_horas',
    'ALUNOS_PORCENTAGEM_Q005_Pai_Nao_Sabe_Escolaridade': 'A005_nao_sabe_escolaridade_pai',
    'ALUNOS_PORCENTAGEM_Q002_Branca': 'A002_alunos_brancos',
    'ALUNOS_PORCENTAGEM_Q003B_Sim_moro_com_pai_padrasto': 'A003B_mora_com_pai_padrasto',
    'ALUNOS_PORCENTAGEM_Q017B_Fazer_Curos_Mais_2_Hora': 'A017B_faz_curso_mais_de_2_horas',
    'ALUNOS_PORCENTAGEM_Q009F_2_Banheiro_Em_Casa': 'A009F_2_banheiros_em_casa',
    'ALUNOS_PORCENTAGEM_Q012_Meio_Transporte_Carro': 'A012_transporte_carro',
    'ALUNOS_PORCENTAGEM_Q006B_Incentiva_Estudar_Vez_Em_Quando': 'A006B_pais_incentiva_estudar',
    'ALUNOS_PORCENTAGEM_Q007_Contratam_Domestica_Vez_Em_Quando': 'A007_vez_enquanto_contratam_domestica',
    'ALUNOS_PORCENTAGEM_Q009B_1_Tablet_Em_Casa': 'A009B_1_tablet_em_casa',
    'ALUNOS_PORCENTAGEM_Q006E_Reuniao_Pais_Quase_Nunca': 'A006E_pais_nunca_vao_a_reuniao',
    'ALUNOS_PORCENTAGEM_Q010A_Sim_Tv_A_Cabo': 'A010A_tem_tv_a_cabo',
    'ALUNOS_PORCENTAGEM_Q003A_Sim_moro_com_mae_madrasta': 'A003A_mora_com_mae_madrasta',
    'ALUNOS_PORCENTAGEM_Q018B_Le_Livros_Quase_Nunca': 'A018B_nuca_le_livros',
    'ALUNOS_PORCENTAGEM_Q006D_Comparecer_aulas_Quase_Sempre': 'A006D_familiar_incentiva_ir_as_aulas',
    'ALUNOS_PORCENTAGEM_Q010I_Sim_Freezer': 'A010I_tem_freezer',
    'ALUNOS_PORCENTAGEM_Q018C_Le_Quadrinhos_Quase_Nunca': 'A018C_nunca_le_quadrinhos',
    'ALUNOS_PORCENTAGEM_Q008B_Sim_Agua_Tratada': 'A008B_tem_agua_tratada',
    'ALUNOS_PORCENTAGEM_Q008C_Sim_Iluminacao_Na_Rua': 'A008C_iluminacao_minha_rua_ok',
    'ALUNOS_PORCENTAGEM_Q010G_Sim_Aspirador_Po': 'A010G_tem_aspirador_de_po',
    'ALUNOS_PORCENTAGEM_Q017D_Estudar_Mais_2_Hora': 'A017D_estuda_mais_de_2_horas',
    'ALUNOS_PORCENTAGEM_Q016_Abandonou_Escola_Nunca': 'A016_nunca_abandonou_escola',
    'PROFESSOR_PORCENTAGEM_Q015_Le_Noticias_Muitas_Vezes': 'P015_le_noticias_muitas_vezes',
    'PROFESSOR_PORCENTAGEM_Q120_Utilizar_Literatura_Para_Gramatica_Semanalmente': 'P120_usa_literatura_para_gramatica_semanalmente',
    'PROFESSOR_PORCENTAGEM_Q036_Software_Nao_Uso': 'P036_nao_usa_software',
    'PROFESSOR_PORCENTAGEM_Q114_Solicitar_Alunos_Copiem_Textos_Semanalmente': 'P114_pede_para_copiar_textos_semanalmente',
    'PROFESSOR_PORCENTAGEM_Q004_Trabalho_Em_2_Escola': 'P004_trabalha_em_2_escolas',
    'ALUNOS_ID_ESCOLA': 'ID_ESCOLA',
    'MEDIA_FINAL': 'MEDIA_FINAL'
})

# %%
df.to_csv('dataset_reduzido_renomeadas.csv', index=False)
df
# Out:
#       A003E_outros_familiares_moram_cmg  \
# 0                              0.090909
# 1                              0.147887
# 2                              0.142857
# 3                              0.146667
# 4                              0.138393
# ...                                 ...
# 8515                           0.123711
# 8516                           0.160000
# 8517                           0.288660
# 8518                           0.103825
# 8519                           0.122581
#
#       A014_estudou_escola_publica_particular  A010B_tem_wifi  \
# 0                                   0.045455        0.893939
# 1                                   0.021127        0.830986
# 2                                   0.035714        0.607143
# 3                                   0.233333        0.820000
# 4                                   0.133929        0.691964
# ...                                      ...             ...
# ...

# %%
df = df.rename(columns={
'A006B_pais_incentiva_estudar': 'A006B_parents_encourage_study',
'A013_ingressou_aos_8_ou_mais': 'A013_joined_at_8_or_more',
'A003E_outros_familiares_moram_cmg': 'A003E_other_family_lives_with_me',
'A009E_2_tvs_em_casa': 'A009E_tvs_at_home',
'A010F_tem_microondas': 'A010F_has_microwave',
'A006D_familiar_incentiva_ir_as_aulas': 'A006D_family_encourages_to_go_to_classes',
'A010H_tem_lavadora_roupas': 'A010H_has_clothes_washer',
'A006A_pais_sempre_conversam_sobre_escola': 'A006A_parents_always_talk_about_school',
'A014_estudou_escola_publica_particular': 'A014_studied_public_school',
'A018C_nunca_le_quadrinhos': 'A018C_never_read_comics',
'A009D_1_quarto_em_casa': 'A009D_1_room_at_home',
'A017A_nao_tem_lazer': 'A017A_no_leisure',
'A018B_nuca_le_livros': 'A018B_never_read_books',
'A010I_tem_freezer': 'A010I_has_freezer',
'A011_mais_de_1_hora_chegar_escola': 'A011_more_than_1_hour_to_school',
'A020_nao_concluiu_eja': 'A020_not_completed_eja',
'A009C_1_pc_em_casa': 'A009C_1_pc_at_home',
'A016_nunca_abandonou_escola': 'A016_never_left_school',
'A008C_iluminacao_minha_rua_ok': 'A008C_lighting_my_street_ok',
'A010E_tem_caragem': 'A010E_has_carriage',
'A005_nao_sabe_escolaridade_pai': 'A005_doesnt_know_fathers_schooling',
'A007_vez_enquanto_contratam_domestica': 'A007_while_hiring_domestics',
'A008B_tem_agua_tratada': 'A008B_has_treated_water',
'A002_alunos_brancos': 'A002_white_students',
'A006_pais_nunca_vao_reunioes': 'A006_parents_never_go_to_meetings',
'A008A_mora_rua_pavimentada': 'A008A_lives_on_paved_street',
'A006C_pais_vez_enquanto_incentivam_fazer_tarefas': 'A006C_parents_always_encourage_doing_chores',
'A010_wifi_em_casa': 'A010_wifi_at_home',
'A012_vai_para_escola_carro': 'A012_go_to_school_car',
'A009B_1_tablet_em_casa': 'A009B_1_tablet_at_home',
'A019_depois_EM_somente_trabalhar': 'A019_after_working_only',
'A010D_tem_mesa_estudo': 'A010D_has_study_tablet',
'A017C_1_a_2_horas_para_trabalhos_domesticos': 'A017C_1_to_2_hours_for_domestic_work',
'A003A_moro_com_mae_madrasta': 'A003A_lives_with_mother_and_grandmother',
'A017B_faco_mais_2_horas_cursos': 'A017B_do_more_2_hours_courses',
'A010C_quarto_so_meu': 'A010C_room_so_mine',
'A003C_nao_moro_com_irmaos': 'A003C_I_dont_live_with_siblings',
'A015_nunca_repovou': 'A015_never_renewed',
'A003B_moro_com_pai_padrasto': 'A003B_I_live_with_father_stepfather',
'A004_nao_sabe_escolaridade_mae': 'A004_doesnt_know_mothers_schooling',
'A003D_nao_moro_com_avos': 'A003D_not_living_with_grandparents',
'A017D_mais_2_horas_estudando_fora_escola': 'A017D_more_2_hours_studying_outside_school',
'A010A_tem_tc_a_cabo': 'A010A_has_tv_a_cable',
'A017E_trabalha_mais_2_horas': 'A017E_works_more_2_hours',
'A009G_nenhum_carro_casa': 'A009G_no_car_home',
'A009F_2_banheiro_casa': 'A009F_2_house_bathroom',
'P082_': 'P082_teachers_worry_about_teaching_quality',
'P004_trabalho_em_2_escolas': 'P004_work_in_2_schools',
'P034_nao_usa_projetor_multimidia': 'P034_doesnt_use_multimedia_projector',
'P022_sempre_assisto_telejornal': 'P022_always_watch_television_newspaper'
})

# %%
df.to_csv('30_colunas_ingles.csv', index=False)
