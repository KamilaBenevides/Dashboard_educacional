# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from metrics import *
import matplotlib.pyplot as plt
import shap
import seaborn as sns
from scipy.stats import linregress
# Out:
# /home/kamila/.pyenv/versions/3.9.0/lib/python3.9/site-packages/xgboost/core.py:265: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc 2.28+) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %%
df = pd.read_csv('novas_30_colunas.csv', encoding='ISO-8859-1')

# %%
pd.set_option('display.max_columns', None)

# %%
escola_id = 43065589
escola_data = df[df['ID_ESCOLA'] == escola_id]
print(escola_data)
# Out:
#       A006B_pais_incentiva_estudar  A013_ingressou_aos_8_ou_mais  \
# 9719                      0.416667                           0.0
#
#       A003E_outros_familiares_moram_cmg  A009E_2_tvs_em_casa  \
# 9719                           0.083333                 0.25
#
#       A010F_tem_microondas  A006D_familiar_incentiva_ir_as_aulas  \
# 9719              0.916667                              0.833333
#
#       A010H_tem_lavadora_roupas  A006A_pais_sempre_conversam_sobre_escola  \
# 9719                        1.0                                      0.25
#
#       A014_estudou_escola_publica_particular  A018C_nunca_le_quadrinhos  \
# 9719                                     0.0                   0.916667
#
#       A009D_1_quarto_em_casa  A017A_nao_tem_lazer  A018B_nuca_le_livros  \
# 9719                     0.0             0.083333                  0.75
#
#       A010I_tem_freezer  A011_mais_de_1_hora_chegar_escola  \
# 9719                1.0                                0.0
#
# ...

# %%
escola_censo = pd.read_csv('../escolas_com_cep.csv', encoding='utf-8', sep=",")

# %%
escola_censo
# Out:
#        NU_ANO_CENSO     NO_REGIAO  CO_REGIAO             NO_UF SG_UF  CO_UF  \
# 0              2019         Norte          1          Rondônia    RO     11
# 1              2019         Norte          1          Rondônia    RO     11
# 2              2019         Norte          1          Rondônia    RO     11
# 3              2019         Norte          1          Rondônia    RO     11
# 4              2019         Norte          1          Rondônia    RO     11
# ...             ...           ...        ...               ...   ...    ...
# 62663          2019  Centro-Oeste          5  Distrito Federal    DF     53
# 62664          2019  Centro-Oeste          5  Distrito Federal    DF     53
# 62665          2019  Centro-Oeste          5  Distrito Federal    DF     53
# 62666          2019  Centro-Oeste          5  Distrito Federal    DF     53
# 62667          2019  Centro-Oeste          5  Distrito Federal    DF     53
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
escola_interesse = escola_censo[escola_censo['CO_ENTIDADE'] == 43065589]
escola_interesse
# Out:
#        NU_ANO_CENSO NO_REGIAO  CO_REGIAO              NO_UF SG_UF  CO_UF  \
# 56091          2019       Sul          4  Rio Grande do Sul    RS     43
#
#         NO_MUNICIPIO  CO_MUNICIPIO          NO_MESORREGIAO  CO_MESORREGIAO  \
# 56091  Coronel Pilar       4305934  Nordeste Rio-grandense            4302
#
#       NO_MICRORREGIAO  CO_MICRORREGIAO  CO_DISTRITO  CO_ENTIDADE  \
# 56091   Caxias do Sul            43016    430593405     43065589
#
#                         NO_ENTIDADE  TP_DEPENDENCIA  \
# 56091  ESC EST ENS MED SAO LOURENCO               2
#
#        TP_CATEGORIA_ESCOLA_PRIVADA  TP_LOCALIZACAO  \
# 56091                            0               1
#
#        TP_LOCALIZACAO_DIFERENCIADA      DS_ENDERECO NU_ENDERECO  \
# 56091                            0  AV DE JULHO 762         762
#
#       DS_COMPLEMENTO NO_BAIRRO      CO_CEP NU_DDD NU_TELEFONE  \
# 56091            NaN    CENTRO  95726000.0     54    34351002
#
# ...
